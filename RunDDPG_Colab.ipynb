# %%
# !pip install swig
# !pip install gymnasium[box2d]
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: swig in c:\users\你姐不信任我\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (4.4.0)
# [notice] A new release of pip is available: 25.0.1 -> 25.3
# [notice] To update, run: C:\Users\你姐不信任我\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip
# Defaulting to user installation because normal site-packages is not writeable
# Collecting gymnasium[box2d]
#   Using cached gymnasium-1.2.2-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: numpy>=1.21.0 in c:\users\你姐不信任我\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from gymnasium[box2d]) (1.26.4)
# Requirement already satisfied: cloudpickle>=1.2.0 in c:\users\你姐不信任我\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from gymnasium[box2d]) (3.1.0)
# Requirement already satisfied: typing-extensions>=4.3.0 in c:\users\你姐不信任我\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from gymnasium[box2d]) (4.12.2)
# Collecting farama-notifications>=0.0.1 (from gymnasium[box2d])
#   Using cached Farama_Notifications-0.0.4-py3-none-any.whl.metadata (558 bytes)
# Collecting box2d-py==2.3.5 (from gymnasium[box2d])
#   Using cached box2d-py-2.3.5.tar.gz (374 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: pygame>=2.1.3 in c:\users\你姐不信任我\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from gymnasium[box2d]) (2.5.2)
# Requirement already satisfied: swig==4.* in c:\users\你姐不信任我\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from gymnasium[box2d]) (4.4.0)
# Using cached Farama_Notifications-0.0.4-py3-none-any.whl (2.5 kB)
# Using cached gymnasium-1.2.2-py3-none-any.whl (952 kB)
# Building wheels for collected packages: box2d-py
#   Building wheel for box2d-py (setup.py): started
#   Building wheel for box2d-py (setup.py): finished with status 'done'
#   Created wheel for box2d-py: filename=box2d_py-2.3.5-cp312-cp312-win_amd64.whl size=433577 sha256=32e382b43f389e0175595ab49f808d7f29ccdae58d405728af1df22e76485ec5
#   Stored in directory: c:\users\你姐不信任我\appdata\local\pip\cache\wheels\2a\e9\60\774da0bcd07f7dc7761a8590fa2d065e4069568e78dcdc3318
# Successfully built box2d-py
# Installing collected packages: farama-notifications, box2d-py, gymnasium
# Successfully installed box2d-py-2.3.5 farama-notifications-0.0.4 gymnasium-1.2.2
# [notice] A new release of pip is available: 25.0.1 -> 25.3
# [notice] To update, run: C:\Users\你姐不信任我\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %% [markdown]
# Add files the following files to local folder (volatile disk) in order to run the python program with the auxilar files:
#
# 1. DDPG.py
# 2. ActorCriticNetworks.py
# 3. ReplayBuffer.py
# 4. Noise.py
# 5. helper.py

# %%
# !python DDPG.py
# Out:
# ^C
