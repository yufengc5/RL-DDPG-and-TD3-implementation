# %%
# !pip install swig
# !pip install gymnasium[box2d]
# Out:
# zsh:1: /Users/yufengchen/Desktop/GIA(25-26)/APRNS/APRNS/bin/pip: bad interpreter: /Users/yufengchen/Desktop/GIA(25-26)/APRNS/Lab3/APRNS/bin/python3.13: no such file or directory
# zsh:1: no matches found: gymnasium[box2d]

# %%
# !pip install torch
# Out:
# zsh:1: /Users/yufengchen/Desktop/GIA(25-26)/APRNS/APRNS/bin/pip: bad interpreter: /Users/yufengchen/Desktop/GIA(25-26)/APRNS/Lab3/APRNS/bin/python3.13: no such file or directory

# %% [markdown]
# Add files the following files to local folder (volatile disk) in order to run the python program with the auxilar files:
#
# 1. DDPG.py
# 2. ActorCriticNetworks.py
# 3. ReplayBuffer.py
# 4. Noise.py
# 5. helper.py

# %%
# !python DDPG.py
# Out:
# Traceback (most recent call last):
#   File "/Users/yufengchen/Desktop/GIA(25-26)/APRNS/Lab7/DDPG.py", line 3, in <module>
#     import torch
# ModuleNotFoundError: No module named 'torch'
